# %%
import torch
from sampling_funcs import StackedRandomGenerator,ODE_motion_sampler

# %%
device = 'cuda:3'
net_save = 'debug_net.pt'

net = torch.load(net_save)['net'].to(device)

# %%
M = 191
N = 191
latents = torch.randn((1,2,M,N),device=device)
sigma = torch.tensor([1],device=device)
out = net(latents,sigma)

print(out.shape)

# %%
190/2
